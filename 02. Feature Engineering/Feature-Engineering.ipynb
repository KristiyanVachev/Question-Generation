# %% [markdown]
# # Common stuff

# %%
#Common imports 
import pandas as pd
from IPython.display import Markdown, display, clear_output
from scipy import stats
from IPython.core.debugger import set_trace
from pathlib import Path

# %% [markdown]
# ## Pickling

# %%
import _pickle as cPickle
from pathlib import Path

def dumpPickle(fileName, content):
    pickleFile = open(fileName, 'wb')
    cPickle.dump(content, pickleFile, -1)
    pickleFile.close()

def loadPickle(fileName):    
    file = open(fileName, 'rb')
    content = cPickle.load(file)
    file.close()
    
    return content
    
def pickleExists(fileName):
    file = Path(fileName)
    
    if file.is_file():
        return True
    
    return False

# %% [markdown]
# #  Reading the dataset

# %%
train = pd.read_json('../data/squad-v1/train-v1.1.json', orient='column')
dev = pd.read_json('../data/squad-v1/dev-v1.1.json', orient='column')

df = pd.concat([train, dev], ignore_index=True)

# %%
df.head()
# Out:
#                                                 data  version
# 0  {'title': 'University_of_Notre_Dame', 'paragra...      1.1
# 1  {'title': 'Beyoncé', 'paragraphs': [{'context'...      1.1
# 2  {'title': 'Montana', 'paragraphs': [{'context'...      1.1
# 3  {'title': 'Genocide', 'paragraphs': [{'context...      1.1
# 4  {'title': 'Antibiotics', 'paragraphs': [{'cont...      1.1

# %%
text = df['data'][0]['paragraphs'][0]['context']
text
# Out:
# 'Architecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.'

# %%
import spacy
from spacy import displacy
from collections import Counter
nlp = spacy.load('en_core_web_md')

# %%
doc = nlp(text)

# %%
for sentence in doc.sents:
    print(len(sentence.text))
    print()
# Out:
# 53
#
# 73
#
# 142
#
# 62
#
# 87
#
# 128
#
# 144

# %%
for token in doc:
    print(token)
# Out:
# Architecturally
# ,
# the
# school
# has
# a
# Catholic
# character
# .
# Atop
# the
# Main
# Building
# 's
# gold
# dome
# is
# a
# golden
# statue
# of
# the
# Virgin
# Mary
# .
# Immediately
# in
# front
# of
# the
# Main
# Building
# and
# facing
# it
# ,
# is
# a
# copper
# statue
# of
# Christ
# with
# arms
# upraised
# with
# the
# legend
# "
# Venite
# Ad
# Me
# Omnes
# "
# .
# Next
# to
# the
# Main
# Building
# is
# the
# Basilica
# of
# the
# Sacred
# Heart
# .
# Immediately
# behind
# the
# basilica
# is
# the
# Grotto
# ,
# a
# Marian
# place
# of
# prayer
# and
# reflection
# .
# It
# is
# a
# replica
# of
# the
# grotto
# at
# Lourdes
# ,
# France
# where
# the
# Virgin
# Mary
# reputedly
# appeared
# to
# Saint
# Bernadette
# Soubirous
# in
# 1858
# .
# At
# the
# end
# of
# the
# main
# drive
# (
# and
# in
# a
# direct
# line
# that
# connects
# through
# 3
# statues
# and
# the
# Gold
# Dome
# )
# ,
# is
# a
# simple
# ,
# modern
# stone
# statue
# of
# Mary
# .

# %%
for noun_chunk in doc.noun_chunks:
    print(noun_chunk)
# Out:
# the school
# a Catholic character
# the Main Building's gold dome
# a golden statue
# the Virgin Mary
# front
# the Main Building
# it
# a copper statue
# Christ
# arms
# the legend
# Venite Ad Me Omnes
# the Main Building
# the Basilica
# the Sacred Heart
# the basilica
# the Grotto
# a Marian place
# prayer
# reflection
# It
# a replica
# the grotto
# Lourdes
# France
# the Virgin Mary
# Saint Bernadette Soubirous
# the end
# the main drive
# a direct line
# 3 statues
# the Gold Dome
# a simple, modern stone statue
# Mary

# %%
for ne in doc.ents:
    print(ne)
# Out:
# Catholic
# the Main Building's
# the Virgin Mary
# the Main Building
# Christ
# Venite Ad Me Omnes
# the Main Building
# the Basilica of the Sacred Heart
# Grotto
# Marian
# Lourdes
# France
# Mary
# Saint Bernadette Soubirous
# 1858
# 3
# the Gold Dome
# Mary

# %%
def NerForWord(text):
    doc = nlp(text)
    
    entitiesFound = len(doc.ents)
    
    if (entitiesFound > 0):
        #TODO - Could potentially find multiple entities in the text. We're returning only the first one.
        return doc.ents[0].label_
    else:
        return ''

# %%
NerForWord('Venite Ad Me Omnes')
# Out:
# 'PERSON'

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)
# Out:
# Architecturally architecturally ADV RB advmod Xxxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True False
# school school NOUN NN nsubj xxxx True False
# has have VERB VBZ ROOT xxx True False
# a a DET DT det x True False
# Catholic catholic ADJ JJ amod Xxxxx True False
# character character NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# Atop atop ADP IN prep Xxxx True False
# the the DET DT det xxx True False
# Main main PROPN NNP compound Xxxx True False
# Building building PROPN NNP poss Xxxxx True False
# 's 's PART POS case 'x False False
# gold gold NOUN NN compound xxxx True False
# dome dome NOUN NN nsubj xxxx True False
# is be VERB VBZ ROOT xx True False
# a a DET DT det x True False
# golden golden ADJ JJ amod xxxx True False
# statue statue NOUN NN attr xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# Virgin virgin PROPN NNP compound Xxxxx True False
# Mary mary PROPN NNP pobj Xxxx True False
# . . PUNCT . punct . False False
# Immediately immediately ADV RB advmod Xxxxx True False
# in in ADP IN prep xx True False
# front front NOUN NN pobj xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# Main main PROPN NNP compound Xxxx True False
# Building building PROPN NNP pobj Xxxxx True False
# and and CCONJ CC cc xxx True False
# facing face VERB VBG conj xxxx True False
# it -PRON- PRON PRP dobj xx True False
# , , PUNCT , punct , False False
# is be VERB VBZ ROOT xx True False
# a a DET DT det x True False
# copper copper NOUN NN compound xxxx True False
# statue statue NOUN NN attr xxxx True False
# of of ADP IN prep xx True False
# Christ christ PROPN NNP pobj Xxxxx True False
# with with ADP IN prep xxxx True False
# arms arm NOUN NNS pobj xxxx True False
# upraised upraised ADJ JJ acl xxxx True False
# with with ADP IN prep xxxx True False
# the the DET DT det xxx True False
# legend legend NOUN NN pobj xxxx True False
# " " PUNCT `` punct " False False
# Venite venite PROPN NNP compound Xxxxx True False
# Ad ad NOUN NN compound Xx True False
# Me -PRON- PRON PRP compound Xx True False
# Omnes omnes PROPN NNPS appos Xxxxx True False
# " " PUNCT '' punct " False False
# . . PUNCT . punct . False False
# Next next ADV RB advmod Xxxx True False
# to to ADP IN prep xx True False
# the the DET DT det xxx True False
# Main main PROPN NNP compound Xxxx True False
# Building building PROPN NNP pobj Xxxxx True False
# is be VERB VBZ ROOT xx True False
# the the DET DT det xxx True False
# Basilica basilica PROPN NNP attr Xxxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# Sacred sacred PROPN NNP compound Xxxxx True False
# Heart heart PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# Immediately immediately ADV RB advmod Xxxxx True False
# behind behind ADP IN prep xxxx True False
# the the DET DT det xxx True False
# basilica basilica NOUN NN pobj xxxx True False
# is be VERB VBZ ROOT xx True False
# the the DET DT det xxx True False
# Grotto grotto PROPN NNP attr Xxxxx True False
# , , PUNCT , punct , False False
# a a DET DT det x True False
# Marian marian PROPN NNP amod Xxxxx True False
# place place NOUN NN appos xxxx True False
# of of ADP IN prep xx True False
# prayer prayer NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True False
# reflection reflection NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
# It -PRON- PRON PRP nsubj Xx True False
# is be VERB VBZ ROOT xx True False
# a a DET DT det x True False
# replica replica NOUN NN attr xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# grotto grotto NOUN NN pobj xxxx True False
# at at ADP IN prep xx True False
# Lourdes lourdes PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# France france PROPN NNP appos Xxxxx True False
# where where ADV WRB advmod xxxx True False
# the the DET DT det xxx True False
# Virgin virgin PROPN NNP compound Xxxxx True False
# Mary mary PROPN NNP nsubj Xxxx True False
# reputedly reputedly ADV RB advmod xxxx True False
# appeared appear VERB VBD relcl xxxx True False
# to to ADP IN prep xx True False
# Saint saint PROPN NNP compound Xxxxx True False
# Bernadette bernadette PROPN NNP compound Xxxxx True False
# Soubirous soubirous PROPN NNP pobj Xxxxx True False
# in in ADP IN prep xx True False
# 1858 1858 NUM CD pobj dddd False False
# . . PUNCT . punct . False False
# At at ADP IN prep Xx True False
# the the DET DT det xxx True False
# end end NOUN NN pobj xxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# main main ADJ JJ amod xxxx True False
# drive drive NOUN NN pobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# and and CCONJ CC cc xxx True False
# in in ADP IN prep xx True False
# a a DET DT det x True False
# direct direct ADJ JJ amod xxxx True False
# line line NOUN NN pobj xxxx True False
# that that ADJ WDT nsubj xxxx True False
# connects connect VERB VBZ relcl xxxx True False
# through through ADP IN prep xxxx True False
# 3 3 NUM CD nummod d False False
# statues statue NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True False
# the the DET DT det xxx True False
# Gold gold PROPN NNP compound Xxxx True False
# Dome dome PROPN NNP conj Xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
# is be VERB VBZ ROOT xx True False
# a a DET DT det x True False
# simple simple ADJ JJ amod xxxx True False
# , , PUNCT , punct , False False
# modern modern ADJ JJ amod xxxx True False
# stone stone NOUN NN compound xxxx True False
# statue statue NOUN NN attr xxxx True False
# of of ADP IN prep xx True False
# Mary mary PROPN NNP pobj Xxxx True False
# . . PUNCT . punct . False False

# %%
spacy.explain('NNP')
# Out:
# 'noun, proper singular'

# %% [markdown]
# # Extracting words and it's features

# %%
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_md')

#There seems to be a bug with spacy's stop words.
from spacy.lang.en.stop_words import STOP_WORDS
for word in STOP_WORDS:
    for w in (word, word[0].capitalize(), word.upper()):
        lex = nlp.vocab[w]
        lex.is_stop = True

# %% [markdown]
# ## Extracting words from a paragrapgh

# %%
text = df['data'][0]['paragraphs'][0]['context']
qas = df['data'][0]['paragraphs'][0]['qas']

# %%
doc = nlp(text)

# %%
#Extract answers and the sentence they are in
answers = []

senStart = 0
senId = 0

for sentence in doc.sents:
    senLen = len(sentence.text)
    
    for answer in qas:
        answerStart = answer['answers'][0]['answer_start']
        
        if (answerStart >= senStart and answerStart < (senStart + senLen)):
            answers.append({'sentenceId': senId, 'text': answer['answers'][0]['text']})
            
    senStart += senLen
    senId += 1

# %%
answers
# Out:
# [{'sentenceId': 1, 'text': 'a golden statue of the Virgin Mary'},
#  {'sentenceId': 2, 'text': 'a copper statue of Christ'},
#  {'sentenceId': 3, 'text': 'the Main Building'},
#  {'sentenceId': 4, 'text': 'a Marian place of prayer and reflection'},
#  {'sentenceId': 5, 'text': 'Saint Bernadette Soubirous'}]

# %%
#TODO - Clean answers from stopwords?

# %%
def tokenIsAnswer(token, sentenceId):
    for i in range(len(answers)):
        if (answers[i]['sentenceId'] == sentenceId):
            if (answers[i]['text'] == token):
                return True
    return False

# %%
tokenIsAnswer('the Main Building', 4)
# Out:
# False

# %%
#Save named entities start points

neStarts = {}
for ne in doc.ents:
    neStarts[ne.start] = ne

# %%
if 6 in neStarts:
    print(neStarts[6].label_)
# Out:
# NORP

# %%
senStarts = []
for sentence in doc.sents:
    senStarts.append(sentence[0].i)
    
def getSentenceForWordPosition(wordPos):
    for i in range(1, len(senStarts)):
        if (wordPos < senStarts[i]):
            return i - 1
    return i

# %%
senStarts
# Out:
# [0, 9, 25, 55, 68, 84, 108]

# %%
getSentenceForWordPosition(108)
# Out:
# 6

# %%
#Creating the dataframe
wordColums = ['text', 'isAnswer', 'titleId', 'paragrapghId', 'sentenceId','wordCount', 'NER', 'POS', 'TAG', 'DEP','shape']
wordDf = pd.DataFrame(columns=wordColums)

#Save to pickle

#load df

#Add new words to array
newWord = ['koala', True, 0, 0, 4, 1, None, None, None, None, 'xxxxx']
newWords = []
#newWords.append(newWord)

#Make array to dataframe
newWordsDf = pd.DataFrame(newWords, columns=wordColums)
newWordsDf

#Merge dataframes
# Out:
# Empty DataFrame
# Columns: [text, isAnswer, titleId, paragrapghId, sentenceId, wordCount, NER, POS, TAG, DEP, shape]
# Index: []

# %%
i = 0
while (i < len(doc)):
    #If the token is a start of a Named Entity, add it and push to index to end of the NE
    if (i in neStarts):
        word = neStarts[i]
        #add word
        currentSentence = getSentenceForWordPosition(word.start)
        wordLen = word.end - word.start
        shape = ''
        for wordIndex in range(word.start, word.end):
            shape += (' ' + doc[wordIndex].shape_)
        
        newWords.append([word.text,
                        tokenIsAnswer(word.text, currentSentence),
                        0,
                        0,
                        currentSentence,
                        wordLen,
                        word.label_,
                        None,
                        None,
                        None,
                        shape])
        i = neStarts[i].end - 1
    #If not a NE, add the word if it's not a stopword or a non-alpha (not regular letters)
    else:
        if (doc[i].is_stop == False and doc[i].is_alpha == True):
            word = doc[i]
            
            currentSentence = getSentenceForWordPosition(i)
            wordLen = 1

            newWords.append([word.text,
                            tokenIsAnswer(word.text, currentSentence),
                            0,
                            0,
                            currentSentence,
                            wordLen,
                            None,
                            word.pos_,
                            word.tag_,
                            word.dep_,
                            word.shape_])
    i += 1

# %%
newWordsDf = pd.DataFrame(newWords, columns=wordColums)
newWordsDf
# Out:
#                                 text  isAnswer  titleId  paragrapghId  \
# 0                    Architecturally     False        0             0
# 1                             school     False        0             0
# 2                           Catholic     False        0             0
# 3                          character     False        0             0
# 4                               Atop     False        0             0
# 5                the Main Building's     False        0             0
# 6                               gold     False        0             0
# 7                               dome     False        0             0
# 8                             golden     False        0             0
# 9                             statue     False        0             0
# 10                   the Virgin Mary     False        0             0
# 11                       Immediately     False        0             0
# 12                 the Main Building     False        0             0
# 13                            facing     False        0             0
# 14                            copper     False        0             0
# 15                            statue     False        0             0
# 16                            Christ     False        0             0
# 17                              arms     False        0             0
# 18                          upraised     False        0             0
# 19                            legend     False        0             0
# 20                Venite Ad Me Omnes     False        0             0
# 21                              Next     False        0             0
# 22                 the Main Building      True        0             0
# 23  the Basilica of the Sacred Heart     False        0             0
# 24                       Immediately     False        0             0
# 25                          basilica     False        0             0
# 26                            Grotto     False        0             0
# 27                            Marian     False        0             0
# 28                             place     False        0             0
# 29                            prayer     False        0             0
# 30                        reflection     False        0             0
# 31                                It     False        0             0
# 32                           replica     False        0             0
# 33                            grotto     False        0             0
# 34                           Lourdes     False        0             0
# 35                            France     False        0             0
# 36                            Virgin     False        0             0
# 37                              Mary     False        0             0
# 38                         reputedly     False        0             0
# 39                          appeared     False        0             0
# 40        Saint Bernadette Soubirous      True        0             0
# 41                              1858     False        0             0
# 42                                At     False        0             0
# 43                               end     False        0             0
# 44                              main     False        0             0
# 45                             drive     False        0             0
# 46                            direct     False        0             0
# 47                              line     False        0             0
# 48                          connects     False        0             0
# 49                                 3     False        0             0
# 50                           statues     False        0             0
# 51                     the Gold Dome     False        0             0
# 52                            simple     False        0             0
# 53                            modern     False        0             0
# 54                             stone     False        0             0
# 55                            statue     False        0             0
# 56                              Mary     False        0             0
#
#     sentenceId  wordCount          NER    POS   TAG       DEP  \
# 0            0          1         None    ADV    RB    advmod
# 1            0          1         None   NOUN    NN     nsubj
# 2            0          1         NORP   None  None      None
# 3            0          1         None   NOUN    NN      dobj
# 4            1          1         None    ADP    IN      prep
# 5            1          4          FAC   None  None      None
# 6            1          1         None   NOUN    NN  compound
# 7            1          1         None   NOUN    NN     nsubj
# 8            1          1         None    ADJ    JJ      amod
# 9            1          1         None   NOUN    NN      attr
# 10           1          3          LAW   None  None      None
# 11           2          1         None    ADV    RB    advmod
# 12           2          3          FAC   None  None      None
# 13           2          1         None   VERB   VBG      conj
# 14           2          1         None   NOUN    NN  compound
# 15           2          1         None   NOUN    NN      attr
# 16           2          1          GPE   None  None      None
# 17           2          1         None   NOUN   NNS      pobj
# 18           2          1         None    ADJ    JJ       acl
# 19           2          1         None   NOUN    NN      pobj
# 20           2          4  WORK_OF_ART   None  None      None
# 21           3          1         None    ADV    RB    advmod
# 22           3          3          ORG   None  None      None
# 23           3          6          LOC   None  None      None
# 24           4          1         None    ADV    RB    advmod
# 25           4          1         None   NOUN    NN      pobj
# 26           4          1          FAC   None  None      None
# 27           4          1         NORP   None  None      None
# 28           4          1         None   NOUN    NN     appos
# 29           4          1         None   NOUN    NN      pobj
# 30           4          1         None   NOUN    NN      conj
# 31           5          1         None   PRON   PRP     nsubj
# 32           5          1         None   NOUN    NN      attr
# 33           5          1         None   NOUN    NN      pobj
# 34           5          1          GPE   None  None      None
# 35           5          1          GPE   None  None      None
# 36           5          1         None  PROPN   NNP  compound
# 37           5          1       PERSON   None  None      None
# 38           5          1         None    ADV    RB    advmod
# 39           5          1         None   VERB   VBD     relcl
# 40           5          3       PERSON   None  None      None
# 41           5          1         DATE   None  None      None
# 42           6          1         None    ADP    IN      prep
# 43           6          1         None   NOUN    NN      pobj
# 44           6          1         None    ADJ    JJ      amod
# 45           6          1         None   NOUN    NN      pobj
# 46           6          1         None    ADJ    JJ      amod
# 47           6          1         None   NOUN    NN      pobj
# 48           6          1         None   VERB   VBZ     relcl
# 49           6          1     CARDINAL   None  None      None
# 50           6          1         None   NOUN   NNS      pobj
# 51           6          3          LOC   None  None      None
# 52           6          1         None    ADJ    JJ      amod
# 53           6          1         None    ADJ    JJ      amod
# 54           6          1         None   NOUN    NN  compound
# 55           6          1         None   NOUN    NN      attr
# 56           6          1       PERSON   None  None      None
#
#                             shape
# 0                           Xxxxx
# 1                            xxxx
# 2                           Xxxxx
# 3                            xxxx
# 4                            Xxxx
# 5               xxx Xxxx Xxxxx 'x
# 6                            xxxx
# 7                            xxxx
# 8                            xxxx
# 9                            xxxx
# 10                 xxx Xxxxx Xxxx
# 11                          Xxxxx
# 12                 xxx Xxxx Xxxxx
# 13                           xxxx
# 14                           xxxx
# 15                           xxxx
# 16                          Xxxxx
# 17                           xxxx
# 18                           xxxx
# 19                           xxxx
# 20              Xxxxx Xx Xx Xxxxx
# 21                           Xxxx
# 22                 xxx Xxxx Xxxxx
# 23   xxx Xxxxx xx xxx Xxxxx Xxxxx
# 24                          Xxxxx
# 25                           xxxx
# 26                          Xxxxx
# 27                          Xxxxx
# 28                           xxxx
# 29                           xxxx
# 30                           xxxx
# 31                             Xx
# 32                           xxxx
# 33                           xxxx
# 34                          Xxxxx
# 35                          Xxxxx
# 36                          Xxxxx
# 37                           Xxxx
# 38                           xxxx
# 39                           xxxx
# 40              Xxxxx Xxxxx Xxxxx
# 41                           dddd
# 42                             Xx
# 43                            xxx
# 44                           xxxx
# 45                           xxxx
# 46                           xxxx
# 47                           xxxx
# 48                           xxxx
# 49                              d
# 50                           xxxx
# 51                  xxx Xxxx Xxxx
# 52                           xxxx
# 53                           xxxx
# 54                           xxxx
# 55                           xxxx
# 56                           Xxxx
