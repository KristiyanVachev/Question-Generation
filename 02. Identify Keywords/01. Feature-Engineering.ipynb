# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ### Spacy
# For the features of the words we're going to use spacy. Once we tokenize the text, we can access features like Part of speech and others.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# #### Displaying progress
# tqdm is a progress bar. It will come usefeful when we extract the answers for all the articles.

# %%
from tqdm import tqdm

# %%
import time

for i in tqdm(range(10)):
    time.sleep(0.5)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:05<00:00,  1.99it/s]

# %% [markdown]
# #### Pickling
# Once we extract all the words from the texts, we'll save them using pickle. Then we can easily use them in the other modules and have to wait for them to generat again.

# %%
import _pickle as cPickle
from pathlib import Path

def dumpPickle(fileName, content):
    pickleFile = open(fileName, 'wb')
    cPickle.dump(content, pickleFile, -1)
    pickleFile.close()

def loadPickle(fileName):    
    file = open(fileName, 'rb')
    content = cPickle.load(file)
    file.close()
    
    return content
    
def pickleExists(fileName):
    file = Path(fileName)
    
    if file.is_file():
        return True
    
    return False

# %% [markdown]
# ## Reading the dataset

# %%
train = pd.read_json('../data/squad-v1/train-v1.1.json', orient='column')
dev = pd.read_json('../data/squad-v1/dev-v1.1.json', orient='column')

df = pd.concat([train, dev], ignore_index=True)

# %%
df.head()
# Out:
#                                                 data  version
# 0  {'title': 'University_of_Notre_Dame', 'paragra...      1.1
# 1  {'title': 'Beyoncé', 'paragraphs': [{'context'...      1.1
# 2  {'title': 'Montana', 'paragraphs': [{'context'...      1.1
# 3  {'title': 'Genocide', 'paragraphs': [{'context...      1.1
# 4  {'title': 'Antibiotics', 'paragraphs': [{'cont...      1.1

# %% [markdown]
# ## Extracting words from a paragrapgh

# %%
currText = df['data'][0]['paragraphs'][0]['context']
currQas = df['data'][0]['paragraphs'][0]['qas']

# %%
currDoc = nlp(currText)

# %%
#Extract answers and the sentence they are in
def extractAnswers(qas, doc):
    answers = []

    senStart = 0
    senId = 0

    for sentence in doc.sents:
        senLen = len(sentence.text)  #sentence lenghts

        for answer in qas:
            answerStart = answer['answers'][0]['answer_start']

            if (answerStart >= senStart and answerStart < (senStart + senLen)):  #if answer falls within the range of current sentence
                answers.append({'sentenceId': senId, 'text': answer['answers'][0]['text']})

        senStart += senLen
        senId += 1
    
    return answers

# %%
currAnswers = extractAnswers(currQas, currDoc)
currAnswers
# Out:
# [{'sentenceId': 1, 'text': 'a golden statue of the Virgin Mary'},
#  {'sentenceId': 2, 'text': 'a copper statue of Christ'},
#  {'sentenceId': 3, 'text': 'the Main Building'},
#  {'sentenceId': 4, 'text': 'a Marian place of prayer and reflection'},
#  {'sentenceId': 5, 'text': 'Saint Bernadette Soubirous'}]

# %%
def tokenIsAnswer(token, sentenceId, answers):
    for i in range(len(answers)):
        if (answers[i]['sentenceId'] == sentenceId):
            if (answers[i]['text'] == token):
                return True
    return False

# %%
tokenIsAnswer('the Main Building', 4, currAnswers)
# Out:
# False

# %%
#Save named entities start points

def getNEStartIndexs(doc):
    neStarts = {}
    for ne in doc.ents:
        neStarts[ne.start] = ne  #position of each named entity
        
    return neStarts

# %%
currNeStarts = getNEStartIndexs(currDoc)

if 6 in currNeStarts:
    print(currNeStarts[6].label_)
# Out:
# NORP

# %%
def getSentenceStartIndexes(doc):
    senStarts = []
    
    for sentence in doc.sents:
        senStarts.append(sentence[0].i)
    
    return senStarts
    
def getSentenceForWordPosition(wordPos, senStarts):   #through word position we find in which sentence does it lie
    for i in range(1, len(senStarts)):
        if (wordPos < senStarts[i]):
            return i - 1

# %%
senStarts = getSentenceStartIndexes(currDoc)
senStarts
# Out:
# [0, 9, 25, 55, 68, 84, 108]

# %%
getSentenceForWordPosition(108, senStarts)

# %%
#Creating the dataframe
wordColums = ['text', 'isAnswer', 'titleId', 'paragrapghId', 'sentenceId','wordCount', 'NER', 'POS', 'TAG', 'DEP','shape']
wordDf = pd.DataFrame(columns=wordColums)

#Save to pickle

#load df

#Add new words to array
newWord = ['koala', True, 0, 0, 4, 1, None, None, None, None, 'xxxxx']
newWords = []
#newWords.append(newWord)

#Make array to dataframe
newWordsDf = pd.DataFrame(newWords, columns=wordColums)
newWordsDf

#Merge dataframes
# Out:
# Empty DataFrame
# Columns: [text, isAnswer, titleId, paragrapghId, sentenceId, wordCount, NER, POS, TAG, DEP, shape]
# Index: []

# %%
def addWordsForParagrapgh(newWords, titleId, paragraphId):
    text = df['data'][titleId]['paragraphs'][paragraphId]['context']
    qas = df['data'][titleId]['paragraphs'][paragraphId]['qas']

    doc = nlp(text)

    answers = extractAnswers(qas, doc)
    neStarts = getNEStartIndexs(doc)
    senStarts = getSentenceStartIndexes(doc)
    
    #index of word in spacy doc text
    i = 0
    
    while (i < len(doc)):
        #If the token is a start of a Named Entity, add it and push to index to end of the NE
        if (i in neStarts):
            word = neStarts[i]
            #add word
            currentSentence = getSentenceForWordPosition(word.start, senStarts)
            wordLen = word.end - word.start
            shape = ''
            for wordIndex in range(word.start, word.end):
                shape += (' ' + doc[wordIndex].shape_)

            newWords.append([word.text,
                            tokenIsAnswer(word.text, currentSentence, answers),
                            titleId,
                            paragraphId,
                            currentSentence,
                            wordLen,
                            word.label_,
                            None,
                            None,
                            None,
                            shape])
            i = neStarts[i].end - 1
        #If not a NE, add the word if it's not a stopword or a non-alpha (not regular letters)
        else:
            if (doc[i].is_stop == False and doc[i].is_alpha == True):
                word = doc[i]

                currentSentence = getSentenceForWordPosition(i, senStarts)
                wordLen = 1

                newWords.append([word.text,
                                tokenIsAnswer(word.text, currentSentence, answers),
                                titleId,
                                paragraphId,
                                currentSentence,
                                wordLen,
                                None,
                                word.pos_,
                                word.tag_,
                                word.dep_,
                                word.shape_])
        i += 1

# %%
#TODO For each token add, for each NE add...

# %%
newWords
# Out:
# []

# %%
addWordsForParagrapgh(newWords, 0, 0)

# %%
newWords[0]
# Out:
# ['Architecturally', False, 0, 0, 0, 1, None, 'ADV', 'RB', 'advmod', 'Xxxxx']

# %%
newWordsDf = pd.DataFrame(newWords, columns=wordColums)
newWordsDf.head()
# Out:
#               text  isAnswer  titleId  paragrapghId  sentenceId  wordCount  \
# 0  Architecturally     False        0             0         0.0          1
# 1           school     False        0             0         0.0          1
# 2         Catholic     False        0             0         0.0          1
# 3        character     False        0             0         0.0          1
# 4             Atop     False        0             0         1.0          1
#
#     NER   POS   TAG     DEP   shape
# 0  None   ADV    RB  advmod   Xxxxx
# 1  None  NOUN    NN   nsubj    xxxx
# 2  NORP  None  None    None   Xxxxx
# 3  None  NOUN    NN    dobj    xxxx
# 4  None   ADP    IN    prep    Xxxx

# %%
newWordsDf[newWordsDf['isAnswer'] == True].head()
# Out:
#                           text  isAnswer  titleId  paragrapghId  sentenceId  \
# 21           the Main Building      True        0             0         3.0
# 38  Saint Bernadette Soubirous      True        0             0         5.0
#
#     wordCount     NER   POS   TAG   DEP               shape
# 21          3     FAC  None  None  None      xxx Xxxx Xxxxx
# 38          3  PERSON  None  None  None   Xxxxx Xxxxx Xxxxx

# %% [markdown]
# Generating a words for 2 titles

# %%
words = []

#titlesCount = len(df['data'])
titlesCount = 2

for titleId in tqdm(range(titlesCount)):
    paragraphsCount = len(df['data'][titleId]['paragraphs'])
        
    for paragraphId in range(paragraphsCount):
        addWordsForParagrapgh(words, titleId, paragraphId)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:14<00:00,  7.08s/it]

# %%
words
# Out:
# [['Architecturally', False, 0, 0, 0, 1, None, 'ADV', 'RB', 'advmod', 'Xxxxx'],
#  ['school', False, 0, 0, 0, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['Catholic', False, 0, 0, 0, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['character', False, 0, 0, 0, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['Atop', False, 0, 0, 1, 1, None, 'ADP', 'IN', 'prep', 'Xxxx'],
#  ["the Main Building's",
#   False,
#   0,
#   0,
#   1,
#   4,
#   'FAC',
#   None,
#   None,
#   None,
#   " xxx Xxxx Xxxxx 'x"],
#  ['gold', False, 0, 0, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['dome', False, 0, 0, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['golden', False, 0, 0, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['statue', False, 0, 0, 1, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['the Virgin Mary.',
#   False,
#   0,
#   0,
#   1,
#   4,
#   'FAC',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxx .'],
#  ['Immediately', False, 0, 0, 2, 1, None, 'ADV', 'RB', 'advmod', 'Xxxxx'],
#  ['the Main Building',
#   False,
#   0,
#   0,
#   2,
#   3,
#   'FAC',
#   None,
#   None,
#   None,
#   ' xxx Xxxx Xxxxx'],
#  ['facing', False, 0, 0, 2, 1, None, 'VERB', 'VBG', 'conj', 'xxxx'],
#  ['copper', False, 0, 0, 2, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['statue', False, 0, 0, 2, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['Christ', False, 0, 0, 2, 1, None, 'PROPN', 'NNP', 'pobj', 'Xxxxx'],
#  ['arms', False, 0, 0, 2, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['upraised', False, 0, 0, 2, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['legend', False, 0, 0, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Venite Ad Me Omnes',
#   False,
#   0,
#   0,
#   2,
#   4,
#   'WORK_OF_ART',
#   None,
#   None,
#   None,
#   ' Xxxxx Xx Xx Xxxxx'],
#  ['the Main Building',
#   True,
#   0,
#   0,
#   3,
#   3,
#   'FAC',
#   None,
#   None,
#   None,
#   ' xxx Xxxx Xxxxx'],
#  ['Basilica', False, 0, 0, 3, 1, None, 'PROPN', 'NNP', 'attr', 'Xxxxx'],
#  ['the Sacred Heart',
#   False,
#   0,
#   0,
#   3,
#   3,
#   'FAC',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx'],
#  ['Immediately', False, 0, 0, 4, 1, None, 'ADV', 'RB', 'advmod', 'Xxxxx'],
#  ['basilica', False, 0, 0, 4, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Grotto', False, 0, 0, 4, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['Marian', False, 0, 0, 4, 1, 'GPE', None, None, None, ' Xxxxx'],
#  ['place', False, 0, 0, 4, 1, None, 'NOUN', 'NN', 'appos', 'xxxx'],
#  ['prayer', False, 0, 0, 4, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['reflection', False, 0, 0, 4, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['replica', False, 0, 0, 5, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['grotto', False, 0, 0, 5, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Lourdes', False, 0, 0, 5, 1, 'GPE', None, None, None, ' Xxxxx'],
#  ['France', False, 0, 0, 5, 1, 'GPE', None, None, None, ' Xxxxx'],
#  ['the Virgin Mary',
#   False,
#   0,
#   0,
#   5,
#   3,
#   'FAC',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxx'],
#  ['reputedly', False, 0, 0, 5, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['appeared', False, 0, 0, 5, 1, None, 'VERB', 'VBD', 'relcl', 'xxxx'],
#  ['Saint Bernadette Soubirous',
#   True,
#   0,
#   0,
#   5,
#   3,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx Xxxxx'],
#  ['1858', False, 0, 0, 5, 1, 'DATE', None, None, None, ' dddd'],
#  ['end', False, 0, 0, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxx'],
#  ['main', False, 0, 0, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['drive', False, 0, 0, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['direct', False, 0, 0, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['line', False, 0, 0, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['connects', False, 0, 0, None, 1, None, 'VERB', 'VBZ', 'relcl', 'xxxx'],
#  ['3', False, 0, 0, None, 1, 'CARDINAL', None, None, None, ' d'],
#  ['statues', False, 0, 0, None, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['the Gold Dome',
#   False,
#   0,
#   0,
#   None,
#   3,
#   'LOC',
#   None,
#   None,
#   None,
#   ' xxx Xxxx Xxxx'],
#  ['simple', False, 0, 0, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['modern', False, 0, 0, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['stone', False, 0, 0, None, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['statue', False, 0, 0, None, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['Mary', False, 0, 0, None, 1, 'PERSON', None, None, None, ' Xxxx'],
#  ['universities', False, 0, 1, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ["Notre Dame's",
#   False,
#   0,
#   1,
#   0,
#   3,
#   'FAC',
#   None,
#   None,
#   None,
#   " Xxxxx Xxxx 'x"],
#  ['students', False, 0, 1, 0, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['run', False, 0, 1, 0, 1, None, 'VERB', 'VBP', 'ROOT', 'xxx'],
#  ['number', False, 0, 1, 0, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['news', False, 0, 1, 0, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['media', False, 0, 1, 0, 1, None, 'NOUN', 'NNS', 'compound', 'xxxx'],
#  ['outlets', False, 0, 1, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['nine', False, 0, 1, 1, 1, 'CARDINAL', None, None, None, ' xxxx'],
#  ['student', False, 0, 1, 1, 1, None, 'NOUN', 'NN', 'npadvmod', 'xxxx'],
#  ['run', False, 0, 1, 1, 1, None, 'NOUN', 'NN', 'amod', 'xxx'],
#  ['outlets', False, 0, 1, 1, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['include', False, 0, 1, 1, 1, None, 'VERB', 'VBP', 'ROOT', 'xxxx'],
#  ['three', True, 0, 1, 1, 1, 'CARDINAL', None, None, None, ' xxxx'],
#  ['newspapers', False, 0, 1, 1, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['radio', False, 0, 1, 1, 1, None, 'NOUN', 'NN', 'nmod', 'xxxx'],
#  ['television', False, 0, 1, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['station', False, 0, 1, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['magazines', False, 0, 1, 1, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['journals', False, 0, 1, 1, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['Begun', False, 0, 1, 2, 1, None, 'VERB', 'VBN', 'advcl', 'Xxxxx'],
#  ['one', False, 0, 1, 2, 1, 'CARDINAL', None, None, None, ' xxx'],
#  ['page', False, 0, 1, 2, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['journal', False, 0, 1, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['September 1876', True, 0, 1, 2, 2, 'DATE', None, None, None, ' Xxxxx dddd'],
#  ['Scholastic', False, 0, 1, 2, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['magazine', False, 0, 1, 2, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['issued', False, 0, 1, 2, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['twice', False, 0, 1, 2, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['monthly', False, 0, 1, 2, 1, 'DATE', None, None, None, ' xxxx'],
#  ['claims', False, 0, 1, 2, 1, None, 'VERB', 'VBZ', 'conj', 'xxxx'],
#  ['oldest', False, 0, 1, 2, 1, None, 'ADJ', 'JJS', 'amod', 'xxxx'],
#  ['continuous', False, 0, 1, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['collegiate', False, 0, 1, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['publication', False, 0, 1, 2, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['the United States',
#   False,
#   0,
#   1,
#   2,
#   3,
#   'GPE',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx'],
#  ['magazine', False, 0, 1, 3, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['Juggler', False, 0, 1, 3, 1, 'PERSON', None, None, None, ' Xxxxx'],
#  ['released', False, 0, 1, 3, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['twice', True, 0, 1, 3, 1, None, 'ADV', 'RB', 'predet', 'xxxx'],
#  ['year', False, 0, 1, 3, 1, None, 'NOUN', 'NN', 'npadvmod', 'xxxx'],
#  ['focuses', False, 0, 1, 3, 1, None, 'VERB', 'VBZ', 'conj', 'xxxx'],
#  ['student', False, 0, 1, 3, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['literature', False, 0, 1, 3, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['artwork', False, 0, 1, 3, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['Dome', False, 0, 1, 4, 1, 'FAC', None, None, None, ' Xxxx'],
#  ['yearbook', False, 0, 1, 4, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['published', False, 0, 1, 4, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['annually', False, 0, 1, 4, 1, 'DATE', None, None, None, ' xxxx'],
#  ['newspapers', False, 0, 1, 5, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['varying', False, 0, 1, 5, 1, None, 'VERB', 'VBG', 'xcomp', 'xxxx'],
#  ['publication', False, 0, 1, 5, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['interests', False, 0, 1, 5, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['Observer', False, 0, 1, 5, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['published', False, 0, 1, 5, 1, None, 'VERB', 'VBN', 'pcomp', 'xxxx'],
#  ['daily', False, 0, 1, 5, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['mainly', False, 0, 1, 5, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['reporting', False, 0, 1, 5, 1, None, 'VERB', 'VBG', 'conj', 'xxxx'],
#  ['university', False, 0, 1, 5, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['news', False, 0, 1, 5, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['staffed', False, 0, 1, 5, 1, None, 'VERB', 'VBN', 'conj', 'xxxx'],
#  ['students', False, 0, 1, 5, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['Notre Dame', False, 0, 1, 5, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ["Saint Mary's",
#   False,
#   0,
#   1,
#   5,
#   3,
#   'PERSON',
#   None,
#   None,
#   None,
#   " Xxxxx Xxxx 'x"],
#  ['College', False, 0, 1, 5, 1, None, 'PROPN', 'NNP', 'conj', 'Xxxxx'],
#  ['Unlike', False, 0, 1, 6, 1, None, 'ADP', 'IN', 'prep', 'Xxxxx'],
#  ['Scholastic', False, 0, 1, 6, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['Dome', False, 0, 1, 6, 1, None, 'PROPN', 'NNP', 'conj', 'Xxxx'],
#  ['Observer', False, 0, 1, 6, 1, None, 'PROPN', 'NNP', 'nsubj', 'Xxxxx'],
#  ['independent', False, 0, 1, 6, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['publication', False, 0, 1, 6, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['faculty', False, 0, 1, 6, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['advisor', False, 0, 1, 6, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['editorial', False, 0, 1, 6, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['oversight', False, 0, 1, 6, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['University', False, 0, 1, 6, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['1987', True, 0, 1, 7, 1, 'DATE', None, None, None, ' dddd'],
#  ['students', False, 0, 1, 7, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['believed', False, 0, 1, 7, 1, None, 'VERB', 'VBD', 'advcl', 'xxxx'],
#  ['Observer', False, 0, 1, 7, 1, None, 'PROPN', 'NNP', 'nsubj', 'Xxxxx'],
#  ['began', False, 0, 1, 7, 1, None, 'VERB', 'VBD', 'ccomp', 'xxxx'],
#  ['conservative', False, 0, 1, 7, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['bias', False, 0, 1, 7, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['liberal', False, 0, 1, 7, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['newspaper', False, 0, 1, 7, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['Common Sense',
#   False,
#   0,
#   1,
#   7,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['published', False, 0, 1, 7, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['Likewise', False, 0, 1, 8, 1, None, 'ADV', 'RB', 'advmod', 'Xxxxx'],
#  ['2003', False, 0, 1, 8, 1, 'DATE', None, None, None, ' dddd'],
#  ['students', False, 0, 1, 8, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['believed', False, 0, 1, 8, 1, None, 'VERB', 'VBD', 'advcl', 'xxxx'],
#  ['paper', False, 0, 1, 8, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['showed', False, 0, 1, 8, 1, None, 'VERB', 'VBD', 'ccomp', 'xxxx'],
#  ['liberal', False, 0, 1, 8, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['bias', False, 0, 1, 8, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['conservative', False, 0, 1, 8, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['paper', False, 0, 1, 8, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['Irish Rover',
#   False,
#   0,
#   1,
#   8,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['went', False, 0, 1, 8, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['production', False, 0, 1, 8, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['paper', False, 0, 1, 9, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['published', False, 0, 1, 9, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['Observer', False, 0, 1, 9, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['three', False, 0, 1, 9, 1, 'CARDINAL', None, None, None, ' xxxx'],
#  ['distributed', False, 0, 1, 9, 1, None, 'VERB', 'VBN', 'advcl', 'xxxx'],
#  ['students', False, 0, 1, 9, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['Finally', False, 0, 1, None, 1, None, 'ADV', 'RB', 'advmod', 'Xxxxx'],
#  ['Spring 2008',
#   False,
#   0,
#   1,
#   None,
#   2,
#   'DATE',
#   None,
#   None,
#   None,
#   ' Xxxxx dddd'],
#  ['undergraduate', False, 0, 1, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['journal', False, 0, 1, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['political', False, 0, 1, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['science', False, 0, 1, None, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['research', False, 0, 1, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Beyond Politics',
#   False,
#   0,
#   1,
#   None,
#   2,
#   'ORG',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['debut', False, 0, 1, None, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['university', False, 0, 2, 0, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['major', False, 0, 2, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['seat', False, 0, 2, 0, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['the Congregation of Holy Cross',
#   False,
#   0,
#   2,
#   0,
#   5,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxx Xxxxx'],
#  ['albeit', False, 0, 2, 0, 1, None, 'SCONJ', 'IN', 'prep', 'xxxx'],
#  ['official', False, 0, 2, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['headquarters', False, 0, 2, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['Rome', True, 0, 2, 0, 1, 'GPE', None, None, None, ' Xxxx'],
#  ['main', False, 0, 2, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['seminary', False, 0, 2, 1, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['Moreau Seminary',
#   True,
#   0,
#   2,
#   1,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['located', False, 0, 2, 1, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['campus', False, 0, 2, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['St. Joseph', False, 0, 2, 1, 2, 'GPE', None, None, None, ' Xx. Xxxxx'],
#  ['lake', False, 0, 2, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['the Main Building',
#   False,
#   0,
#   2,
#   1,
#   3,
#   'FAC',
#   None,
#   None,
#   None,
#   ' xxx Xxxx Xxxxx'],
#  ['Old College', True, 0, 2, 2, 2, 'ORG', None, None, None, ' Xxx Xxxxx'],
#  ['oldest', False, 0, 2, 2, 1, None, 'ADJ', 'JJS', 'amod', 'xxxx'],
#  ['building', False, 0, 2, 2, 1, None, 'NOUN', 'NN', 'appos', 'xxxx'],
#  ['campus', False, 0, 2, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['located', False, 0, 2, 2, 1, None, 'VERB', 'VBN', 'conj', 'xxxx'],
#  ['near', False, 0, 2, 2, 1, None, 'ADP', 'IN', 'prep', 'xxxx'],
#  ['shore', False, 0, 2, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['St. Mary', False, 0, 2, 2, 2, 'GPE', None, None, None, ' Xx. Xxxx'],
#  ['lake', False, 0, 2, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['houses', False, 0, 2, 2, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['undergraduate', False, 0, 2, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['seminarians', False, 0, 2, 2, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['Retired', False, 0, 2, 3, 1, None, 'VERB', 'VBN', 'amod', 'Xxxxx'],
#  ['priests', False, 0, 2, 3, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['brothers', False, 0, 2, 3, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['reside', False, 0, 2, 3, 1, None, 'VERB', 'VBP', 'ROOT', 'xxxx'],
#  ['Fatima House',
#   False,
#   0,
#   2,
#   3,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['retreat', False, 0, 2, 3, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['center', False, 0, 2, 3, 1, None, 'NOUN', 'NN', 'appos', 'xxxx'],
#  ['Holy Cross', False, 0, 2, 3, 2, 'ORG', None, None, None, ' Xxxx Xxxxx'],
#  ['House', False, 0, 2, 3, 1, None, 'PROPN', 'NNP', 'npadvmod', 'Xxxxx'],
#  ['Columba Hall', False, 0, 2, 3, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ['near', False, 0, 2, 3, 1, None, 'ADP', 'IN', 'prep', 'xxxx'],
#  ['Grotto', False, 0, 2, 3, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['university', False, 0, 2, 4, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['the Moreau Seminary',
#   False,
#   0,
#   2,
#   4,
#   3,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx'],
#  ['ties', False, 0, 2, 4, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['theologian', False, 0, 2, 4, 1, None, 'ADJ', 'JJ', 'compound', 'xxxx'],
#  ['Frederick Buechner',
#   False,
#   0,
#   2,
#   4,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['Catholic', False, 0, 2, None, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['Buechner', False, 0, 2, None, 1, 'PERSON', None, None, None, ' Xxxxx'],
#  ['praised', False, 0, 2, None, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['writers', False, 0, 2, None, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['Notre Dame', False, 0, 2, None, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ['Moreau Seminary',
#   False,
#   0,
#   2,
#   None,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['created', False, 0, 2, None, 1, None, 'VERB', 'VBD', 'ccomp', 'xxxx'],
#  ['Buechner Prize for Preaching',
#   False,
#   0,
#   2,
#   None,
#   4,
#   'WORK_OF_ART',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx xxx Xxxxx'],
#  ['The College of Engineering',
#   False,
#   0,
#   3,
#   0,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' Xxx Xxxxx xx Xxxxx'],
#  ['established', False, 0, 3, 0, 1, None, 'VERB', 'VBN', 'ccomp', 'xxxx'],
#  ['1920', True, 0, 3, 0, 1, 'DATE', None, None, None, ' dddd'],
#  ['early', False, 0, 3, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['courses', False, 0, 3, 0, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['civil', False, 0, 3, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['mechanical', False, 0, 3, 0, 1, None, 'ADJ', 'JJ', 'conj', 'xxxx'],
#  ['engineering', False, 0, 3, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['the College of Science',
#   True,
#   0,
#   3,
#   0,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxxx'],
#  ['the 1870s', True, 0, 3, 0, 2, 'DATE', None, None, None, ' xxx ddddx'],
#  ['Today', False, 0, 3, 1, 1, 'DATE', None, None, None, ' Xxxxx'],
#  ['college', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['housed', False, 0, 3, 1, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['Fitzpatrick', False, 0, 3, 1, 1, 'PRODUCT', None, None, None, ' Xxxxx'],
#  ['Cushing', False, 0, 3, 1, 1, 'PRODUCT', None, None, None, ' Xxxxx'],
#  ['Stinson-Remick Halls of Engineering',
#   False,
#   0,
#   3,
#   1,
#   6,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx - Xxxxx Xxxxx xx Xxxxx'],
#  ['includes', False, 0, 3, 1, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['five', True, 0, 3, 1, 1, 'CARDINAL', None, None, None, ' xxxx'],
#  ['departments', False, 0, 3, 1, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['study', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['aerospace', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['mechanical', False, 0, 3, 1, 1, None, 'ADJ', 'JJ', 'conj', 'xxxx'],
#  ['engineering', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['chemical', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['biomolecular', False, 0, 3, 1, 1, None, 'ADJ', 'JJ', 'conj', 'xxxx'],
#  ['engineering', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['civil', False, 0, 3, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['engineering', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['geological', False, 0, 3, 1, 1, None, 'ADJ', 'JJ', 'conj', 'xxxx'],
#  ['sciences', False, 0, 3, 1, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['computer', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['science', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['engineering', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['electrical', False, 0, 3, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['engineering', False, 0, 3, 1, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['eight', True, 0, 3, 1, 1, 'CARDINAL', None, None, None, ' xxxx'],
#  ['B.S.', False, 0, 3, 1, 1, 'GPE', None, None, None, ' X.X.'],
#  ['degrees', False, 0, 3, 1, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['offered', False, 0, 3, 1, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['Additionally', False, 0, 3, None, 1, None, 'ADV', 'RB', 'advmod', 'Xxxxx'],
#  ['college', False, 0, 3, None, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['offers', False, 0, 3, None, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['five-year', False, 0, 3, None, 3, 'DATE', None, None, None, ' xxxx - xxxx'],
#  ['dual', False, 0, 3, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['degree', False, 0, 3, None, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['programs', False, 0, 3, None, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['the Colleges of Arts',
#   False,
#   0,
#   3,
#   None,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxx'],
#  ['Letters', False, 0, 3, None, 1, None, 'PROPN', 'NNPS', 'conj', 'Xxxxx'],
#  ['Business', False, 0, 3, None, 1, None, 'PROPN', 'NNP', 'pobj', 'Xxxxx'],
#  ['awarding', False, 0, 3, None, 1, None, 'VERB', 'VBG', 'advcl', 'xxxx'],
#  ['additional', False, 0, 3, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['B.A.', False, 0, 3, None, 1, 'GPE', None, None, None, ' X.X.'],
#  ['Master of Business Administration',
#   False,
#   0,
#   3,
#   None,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' Xxxxx xx Xxxxx Xxxxx'],
#  ['MBA', False, 0, 3, None, 1, 'WORK_OF_ART', None, None, None, ' XXX'],
#  ['degrees', False, 0, 3, None, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['respectively', False, 0, 3, None, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ["Notre Dame's",
#   False,
#   0,
#   4,
#   0,
#   3,
#   'FAC',
#   None,
#   None,
#   None,
#   " Xxxxx Xxxx 'x"],
#  ['undergraduate', False, 0, 4, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['students', False, 0, 4, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['one', False, 0, 4, 0, 1, 'CARDINAL', None, None, None, ' xxx'],
#  ['five', True, 0, 4, 0, 1, 'CARDINAL', None, None, None, ' xxxx'],
#  ['undergraduate', False, 0, 4, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['colleges', False, 0, 4, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['school', False, 0, 4, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['the First Year',
#   False,
#   0,
#   4,
#   0,
#   3,
#   'DATE',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxx'],
#  ['Studies', False, 0, 4, 0, 1, None, 'PROPN', 'NNPS', 'pobj', 'Xxxxx'],
#  ['program', False, 0, 4, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['The First Year of Studies',
#   False,
#   0,
#   4,
#   1,
#   5,
#   'EVENT',
#   None,
#   None,
#   None,
#   ' Xxx Xxxxx Xxxx xx Xxxxx'],
#  ['program', False, 0, 4, 1, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['established', False, 0, 4, 1, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['1962', False, 0, 4, 1, 1, 'DATE', None, None, None, ' dddd'],
#  ['guide', False, 0, 4, 1, 1, None, 'VERB', 'VB', 'advcl', 'xxxx'],
#  ['incoming', False, 0, 4, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['freshmen', False, 0, 4, 1, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['their first year',
#   False,
#   0,
#   4,
#   1,
#   3,
#   'DATE',
#   None,
#   None,
#   None,
#   ' xxxx xxxx xxxx'],
#  ['school', False, 0, 4, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['declared', False, 0, 4, 1, 1, None, 'VERB', 'VBN', 'advcl', 'xxxx'],
#  ['major', False, 0, 4, 1, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['student', False, 0, 4, 2, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['given', False, 0, 4, 2, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['academic', False, 0, 4, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['advisor', False, 0, 4, 2, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['program', False, 0, 4, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['helps', False, 0, 4, 2, 1, None, 'VERB', 'VBZ', 'relcl', 'xxxx'],
#  ['choose', False, 0, 4, 2, 1, None, 'VERB', 'VB', 'xcomp', 'xxxx'],
#  ['classes', False, 0, 4, 2, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['exposure', False, 0, 4, 2, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['major', False, 0, 4, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['interested', False, 0, 4, 2, 1, None, 'ADJ', 'JJ', 'acomp', 'xxxx'],
#  ['program', False, 0, 4, 3, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['includes', False, 0, 4, 3, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['a Learning Resource Center',
#   False,
#   0,
#   4,
#   3,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' x Xxxxx Xxxxx Xxxxx'],
#  ['provides', False, 0, 4, 3, 1, None, 'VERB', 'VBZ', 'relcl', 'xxxx'],
#  ['time', False, 0, 4, 3, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['management', False, 0, 4, 3, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['collaborative', False, 0, 4, 3, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['learning', False, 0, 4, 3, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['subject', False, 0, 4, 3, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['tutoring', False, 0, 4, 3, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['program', False, 0, 4, None, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['recognized', False, 0, 4, None, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['previously', False, 0, 4, None, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['U.S. News & World Report',
#   False,
#   0,
#   4,
#   None,
#   5,
#   'ORG',
#   None,
#   None,
#   None,
#   ' X.X. Xxxx & Xxxxx Xxxxx'],
#  ['outstanding', False, 0, 4, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['university', False, 0, 5, 0, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['offered', False, 0, 5, 0, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['graduate', False, 0, 5, 0, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['degrees', False, 0, 5, 0, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['form', False, 0, 5, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['a Master of Arts',
#   False,
#   0,
#   5,
#   0,
#   4,
#   'WORK_OF_ART',
#   None,
#   None,
#   None,
#   ' x Xxxxx xx Xxxx'],
#  ['MA', False, 0, 5, 0, 1, None, 'PROPN', 'NNP', 'appos', 'XX'],
#  ['1854–1855 academic year',
#   False,
#   0,
#   5,
#   0,
#   3,
#   'DATE',
#   None,
#   None,
#   None,
#   ' dddd–dddd xxxx xxxx'],
#  ['program', False, 0, 5, 1, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['expanded', False, 0, 5, 1, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['include', False, 0, 5, 1, 1, None, 'VERB', 'VB', 'xcomp', 'xxxx'],
#  ['Master of Laws',
#   False,
#   0,
#   5,
#   1,
#   3,
#   'WORK_OF_ART',
#   None,
#   None,
#   None,
#   ' Xxxxx xx Xxxx'],
#  ['Master', False, 0, 5, 1, 1, None, 'PROPN', 'NNP', 'conj', 'Xxxxx'],
#  ['Civil', False, 0, 5, 1, 1, None, 'PROPN', 'NNP', 'compound', 'Xxxxx'],
#  ['Engineering', False, 0, 5, 1, 1, None, 'PROPN', 'NNP', 'pobj', 'Xxxxx'],
#  ['early', False, 0, 5, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['stages', False, 0, 5, 1, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['growth', False, 0, 5, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['formal', False, 0, 5, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['graduate', False, 0, 5, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['school', False, 0, 5, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['education', False, 0, 5, 1, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['developed', False, 0, 5, 1, 1, None, 'VERB', 'VBN', 'advcl', 'xxxx'],
#  ['thesis', False, 0, 5, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['required', False, 0, 5, 1, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['receive', False, 0, 5, 1, 1, None, 'VERB', 'VB', 'xcomp', 'xxxx'],
#  ['degrees', False, 0, 5, 1, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['changed', False, 0, 5, 2, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['1924', True, 0, 5, 2, 1, 'DATE', None, None, None, ' dddd'],
#  ['formal', False, 0, 5, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['requirements', False, 0, 5, 2, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['developed', False, 0, 5, 2, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['graduate', False, 0, 5, 2, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['degrees', False, 0, 5, 2, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['including', False, 0, 5, 2, 1, None, 'VERB', 'VBG', 'prep', 'xxxx'],
#  ['offering', False, 0, 5, 2, 1, None, 'VERB', 'VBG', 'pcomp', 'xxxx'],
#  ['Doctorate', False, 0, 5, 2, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['PhD', False, 0, 5, 2, 1, 'WORK_OF_ART', None, None, None, ' XxX'],
#  ['degrees', False, 0, 5, 2, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['Today', False, 0, 5, 3, 1, 'DATE', None, None, None, ' Xxxxx'],
#  ['five', False, 0, 5, 3, 1, 'CARDINAL', None, None, None, ' xxxx'],
#  ['colleges', False, 0, 5, 3, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['offer', False, 0, 5, 3, 1, None, 'VERB', 'VBP', 'ROOT', 'xxxx'],
#  ['graduate', False, 0, 5, 3, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['education', False, 0, 5, 3, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['departments', False, 0, 5, 4, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['the College of Arts and Letters',
#   False,
#   0,
#   5,
#   4,
#   6,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxx xxx Xxxxx'],
#  ['offer', False, 0, 5, 4, 1, None, 'VERB', 'VBP', 'ROOT', 'xxxx'],
#  ['PhD', False, 0, 5, 4, 1, 'WORK_OF_ART', None, None, None, ' XxX'],
#  ['programs', False, 0, 5, 4, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['professional', False, 0, 5, 4, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['Master', False, 0, 5, 4, 1, None, 'PROPN', 'NNP', 'advcl', 'Xxxxx'],
#  ['Divinity', False, 0, 5, 4, 1, None, 'PROPN', 'NNP', 'pobj', 'Xxxxx'],
#  ['program', False, 0, 5, 5, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['exists', False, 0, 5, 5, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['departments', False, 0, 5, 6, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['the College of Science',
#   False,
#   0,
#   5,
#   6,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxxx'],
#  ['offer', False, 0, 5, 6, 1, None, 'VERB', 'VBP', 'ROOT', 'xxxx'],
#  ['PhD', False, 0, 5, 6, 1, 'WORK_OF_ART', None, None, None, ' XxX'],
#  ['programs', False, 0, 5, 6, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['the Department of Pre-Professional Studies',
#   False,
#   0,
#   5,
#   6,
#   7,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxx - Xxxxx Xxxxx'],
#  ['The School of Architecture',
#   False,
#   0,
#   5,
#   7,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' Xxx Xxxxx xx Xxxxx'],
#  ['offers', False, 0, 5, 7, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['a Master of Architecture',
#   False,
#   0,
#   5,
#   7,
#   4,
#   'WORK_OF_ART',
#   None,
#   None,
#   None,
#   ' x Xxxxx xx Xxxxx'],
#  ['departments', False, 0, 5, 7, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['the College of Engineering',
#   False,
#   0,
#   5,
#   7,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxxx'],
#  ['offer', False, 0, 5, 7, 1, None, 'VERB', 'VBP', 'advcl', 'xxxx'],
#  ['PhD', False, 0, 5, 7, 1, 'WORK_OF_ART', None, None, None, ' XxX'],
#  ['programs', False, 0, 5, 7, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['The College of Business',
#   False,
#   0,
#   5,
#   8,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' Xxx Xxxxx xx Xxxxx'],
#  ['offers', False, 0, 5, 8, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['multiple', False, 0, 5, 8, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['professional', False, 0, 5, 8, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['programs', False, 0, 5, 8, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['including', False, 0, 5, 8, 1, None, 'VERB', 'VBG', 'prep', 'xxxx'],
#  ['MBA', False, 0, 5, 8, 1, 'WORK_OF_ART', None, None, None, ' XXX'],
#  ['Master of Science in Accountancy',
#   False,
#   0,
#   5,
#   8,
#   5,
#   'WORK_OF_ART',
#   None,
#   None,
#   None,
#   ' Xxxxx xx Xxxxx xx Xxxxx'],
#  ['programs', False, 0, 5, 8, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['operates', False, 0, 5, 9, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['facilities', False, 0, 5, 9, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['Chicago', False, 0, 5, 9, 1, 'GPE', None, None, None, ' Xxxxx'],
#  ['Cincinnati', False, 0, 5, 9, 1, 'GPE', None, None, None, ' Xxxxx'],
#  ['executive', False, 0, 5, 9, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['MBA', False, 0, 5, 9, 1, 'WORK_OF_ART', None, None, None, ' XXX'],
#  ['program', False, 0, 5, 9, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Additionally', False, 0, 5, None, 1, None, 'ADV', 'RB', 'advmod', 'Xxxxx'],
#  ['the Alliance for Catholic Education',
#   False,
#   0,
#   5,
#   None,
#   5,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xxx Xxxxx Xxxxx'],
#  ['program', False, 0, 5, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['offers', False, 0, 5, None, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['a Master of Education',
#   False,
#   0,
#   5,
#   None,
#   4,
#   'WORK_OF_ART',
#   None,
#   None,
#   None,
#   ' x Xxxxx xx Xxxxx'],
#  ['program', False, 0, 5, None, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['students', False, 0, 5, None, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['study', False, 0, 5, None, 1, None, 'VERB', 'VBP', 'relcl', 'xxxx'],
#  ['university', False, 0, 5, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['the summer', False, 0, 5, None, 2, 'DATE', None, None, None, ' xxx xxxx'],
#  ['teach', False, 0, 5, None, 1, None, 'VERB', 'VB', 'conj', 'xxxx'],
#  ['Catholic', False, 0, 5, None, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['elementary', False, 0, 5, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['schools', False, 0, 5, None, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['middle', False, 0, 5, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['schools', False, 0, 5, None, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['high', False, 0, 5, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['schools', False, 0, 5, None, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['the Southern United States',
#   False,
#   0,
#   5,
#   None,
#   4,
#   'GPE',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx Xxxxx'],
#  ['two school years',
#   False,
#   0,
#   5,
#   None,
#   3,
#   'DATE',
#   None,
#   None,
#   None,
#   ' xxx xxxx xxxx'],
#  ['The Joan B. Kroc Institute for International Peace Studies',
#   False,
#   0,
#   6,
#   0,
#   9,
#   'ORG',
#   None,
#   None,
#   None,
#   ' Xxx Xxxx X. Xxxx Xxxxx xxx Xxxxx Xxxxx Xxxxx'],
#  ['the University of Notre Dame',
#   False,
#   0,
#   6,
#   0,
#   5,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxxx Xxxx'],
#  ['dedicated', False, 0, 6, 0, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['research', False, 0, 6, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['education', False, 0, 6, 0, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['outreach', False, 0, 6, 0, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['causes', False, 0, 6, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['violent', False, 0, 6, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['conflict', False, 0, 6, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['conditions', False, 0, 6, 0, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['sustainable', False, 0, 6, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['peace', False, 0, 6, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['offers', False, 0, 6, 1, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['PhD', False, 0, 6, 1, 1, 'WORK_OF_ART', None, None, None, ' XxX'],
#  ['Master', False, 0, 6, 1, 1, None, 'PROPN', 'NNP', 'conj', 'Xxxxx'],
#  ['undergraduate', False, 0, 6, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['degrees', False, 0, 6, 1, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['peace', False, 0, 6, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['studies', False, 0, 6, 1, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['founded', False, 0, 6, 2, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['1986', True, 0, 6, 2, 1, 'DATE', None, None, None, ' dddd'],
#  ['donations', False, 0, 6, 2, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['Joan B. Kroc',
#   False,
#   0,
#   6,
#   2,
#   3,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxx X. Xxxx'],
#  ['widow', False, 0, 6, 2, 1, None, 'NOUN', 'NN', 'appos', 'xxxx'],
#  ["McDonald's", True, 0, 6, 2, 2, 'ORG', None, None, None, " XxXxxxx 'x"],
#  ['owner', False, 0, 6, 2, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['Ray Kroc', True, 0, 6, 2, 2, 'PERSON', None, None, None, ' Xxx Xxxx'],
#  ['institute', False, 0, 6, 3, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['inspired', False, 0, 6, 3, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['vision', False, 0, 6, 3, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Theodore M. Hesburgh CSC',
#   False,
#   0,
#   6,
#   3,
#   4,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx X. Xxxxx XXX'],
#  ['President', False, 0, 6, 3, 1, None, 'PROPN', 'NNP', 'compound', 'Xxxxx'],
#  ['Emeritus', False, 0, 6, 3, 1, 'PERSON', None, None, None, ' Xxxxx'],
#  ['the University of Notre Dame',
#   False,
#   0,
#   6,
#   3,
#   5,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxxx Xxxx'],
#  ['institute', False, 0, 6, None, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['contributed', False, 0, 6, None, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['international', False, 0, 6, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['policy', False, 0, 6, None, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['discussions', False, 0, 6, None, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['peace', False, 0, 6, None, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['building', False, 0, 6, None, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['practices', False, 0, 6, None, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['library', False, 0, 7, 0, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['system', False, 0, 7, 0, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['university', False, 0, 7, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['divided', False, 0, 7, 0, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['main', False, 0, 7, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['library', False, 0, 7, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['colleges', False, 0, 7, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['schools', False, 0, 7, 0, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['main', False, 0, 7, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['building', False, 0, 7, 1, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['14', True, 0, 7, 1, 1, 'CARDINAL', None, None, None, ' dd'],
#  ['story', False, 0, 7, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['Theodore M. Hesburgh Library',
#   True,
#   0,
#   7,
#   1,
#   4,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx X. Xxxxx Xxxxx'],
#  ['completed', False, 0, 7, 1, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['1963', True, 0, 7, 1, 1, 'DATE', None, None, None, ' dddd'],
#  ['third', False, 0, 7, 1, 1, 'ORDINAL', None, None, None, ' xxxx'],
#  ['building', False, 0, 7, 1, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['house', False, 0, 7, 1, 1, None, 'VERB', 'VB', 'relcl', 'xxxx'],
#  ['main', False, 0, 7, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['collection', False, 0, 7, 1, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['books', False, 0, 7, 1, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['library', False, 0, 7, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['adorned', False, 0, 7, 2, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['the Word of Life',
#   False,
#   0,
#   7,
#   2,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxx xx Xxxx'],
#  ['mural', False, 0, 7, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['designed', False, 0, 7, 2, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['artist', False, 0, 7, 2, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['Millard Sheets',
#   True,
#   0,
#   7,
#   2,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['mural', False, 0, 7, None, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['popularly', False, 0, 7, None, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['known', False, 0, 7, None, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['Touchdown',
#   False,
#   0,
#   7,
#   None,
#   1,
#   None,
#   'PROPN',
#   'NNP',
#   'compound',
#   'Xxxxx'],
#  ['Jesus', False, 0, 7, None, 1, None, 'PROPN', 'NNP', 'pobj', 'Xxxxx'],
#  ['proximity', False, 0, 7, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Notre Dame Stadium',
#   False,
#   0,
#   7,
#   None,
#   3,
#   'FAC',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxx Xxxxx'],
#  ['Jesus', False, 0, 7, None, 1, 'PERSON', None, None, None, ' Xxxxx'],
#  ['arms', False, 0, 7, None, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['appearing', False, 0, 7, None, 1, None, 'VERB', 'VBG', 'acl', 'xxxx'],
#  ['signal', False, 0, 7, None, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['touchdown', False, 0, 7, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Notre Dame', False, 0, 8, 0, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ['known', False, 0, 8, 0, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['competitive', False, 0, 8, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['admissions', False, 0, 8, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['incoming', False, 0, 8, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['class', False, 0, 8, 0, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['enrolling', False, 0, 8, 0, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['fall 2015', False, 0, 8, 0, 2, 'DATE', None, None, None, ' xxxx dddd'],
#  ['admitting', False, 0, 8, 0, 1, None, 'VERB', 'VBG', 'pcomp', 'xxxx'],
#  ['3,577', True, 0, 8, 0, 1, 'CARDINAL', None, None, None, ' d,ddd'],
#  ['pool', False, 0, 8, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['18,156', False, 0, 8, 0, 1, 'CARDINAL', None, None, None, ' dd,ddd'],
#  ['19.7%', True, 0, 8, 0, 2, 'PERCENT', None, None, None, ' dd.d %'],
#  ['academic', False, 0, 8, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['profile', False, 0, 8, 1, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['enrolled', False, 0, 8, 1, 1, None, 'VERB', 'VBN', 'amod', 'xxxx'],
#  ['class', False, 0, 8, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['continues', False, 0, 8, 1, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['rate', False, 0, 8, 1, 1, None, 'VERB', 'VB', 'xcomp', 'xxxx'],
#  ['10 to 15', False, 0, 8, 1, 3, 'CARDINAL', None, None, None, ' dd xx dd'],
#  ['nation', False, 0, 8, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['national', False, 0, 8, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['research', False, 0, 8, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['universities', False, 0, 8, 1, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['university', False, 0, 8, 2, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['practices', False, 0, 8, 2, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['non', False, 0, 8, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxx'],
#  ['restrictive', False, 0, 8, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['early', False, 0, 8, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['action', False, 0, 8, 2, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['policy', False, 0, 8, 2, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['allows', False, 0, 8, 2, 1, None, 'VERB', 'VBZ', 'relcl', 'xxxx'],
#  ['admitted', False, 0, 8, 2, 1, None, 'VERB', 'VBN', 'ccomp', 'xxxx'],
#  ['students', False, 0, 8, 2, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['consider', False, 0, 8, 2, 1, None, 'VERB', 'VB', 'ccomp', 'xxxx'],
#  ['admission', False, 0, 8, 2, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['Notre Dame', False, 0, 8, 2, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ['colleges', False, 0, 8, 2, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['accepted', False, 0, 8, 2, 1, None, 'VERB', 'VBN', 'relcl', 'xxxx'],
#  ['1,400', False, 0, 8, 3, 1, 'CARDINAL', None, None, None, ' d,ddd'],
#  ['3,577', False, 0, 8, 3, 1, 'CARDINAL', None, None, None, ' d,ddd'],
#  ['39.1%', True, 0, 8, 3, 2, 'PERCENT', None, None, None, ' dd.d %'],
#  ['admitted', False, 0, 8, 3, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['early', False, 0, 8, 3, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['action', False, 0, 8, 3, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['plan', False, 0, 8, 3, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Admitted', False, 0, 8, 4, 1, None, 'VERB', 'VBN', 'amod', 'Xxxxx'],
#  ['students', False, 0, 8, 4, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['came', False, 0, 8, 4, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['1,311', False, 0, 8, 4, 1, 'CARDINAL', None, None, None, ' d,ddd'],
#  ['high', False, 0, 8, 4, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['schools', False, 0, 8, 4, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['average', False, 0, 8, 4, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['student', False, 0, 8, 4, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['traveled', False, 0, 8, 4, 1, None, 'VERB', 'VBD', 'conj', 'xxxx'],
#  ['more than 750 miles',
#   True,
#   0,
#   8,
#   4,
#   4,
#   'QUANTITY',
#   None,
#   None,
#   None,
#   ' xxxx xxxx ddd xxxx'],
#  ['Notre Dame', False, 0, 8, 4, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ['making', False, 0, 8, 4, 1, None, 'VERB', 'VBG', 'advcl', 'xxxx'],
#  ['arguably', False, 0, 8, 4, 1, None, 'ADV', 'RB', 'ccomp', 'xxxx'],
#  ['representative', False, 0, 8, 4, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['university', False, 0, 8, 4, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['the United States',
#   False,
#   0,
#   8,
#   4,
#   3,
#   'GPE',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx'],
#  ['entering', False, 0, 8, None, 1, None, 'VERB', 'VBG', 'amod', 'xxxx'],
#  ['students', False, 0, 8, None, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['begin', False, 0, 8, None, 1, None, 'VERB', 'VBP', 'advcl', 'xxxx'],
#  ['the College of the First Year of Studies',
#   False,
#   0,
#   8,
#   None,
#   8,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx xxx Xxxxx Xxxx xx Xxxxx'],
#  ['25%', False, 0, 8, None, 2, 'PERCENT', None, None, None, ' dd %'],
#  ['indicated', False, 0, 8, None, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['plan', False, 0, 8, None, 1, None, 'VERB', 'VBP', 'ccomp', 'xxxx'],
#  ['study', False, 0, 8, None, 1, None, 'VERB', 'VB', 'xcomp', 'xxxx'],
#  ['liberal', False, 0, 8, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['arts', False, 0, 8, None, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['social', False, 0, 8, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['sciences', False, 0, 8, None, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['24%', False, 0, 8, None, 2, 'PERCENT', None, None, None, ' dd %'],
#  ['engineering', False, 0, 8, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['24%', False, 0, 8, None, 2, 'PERCENT', None, None, None, ' dd %'],
#  ['business', False, 0, 8, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['24%', False, 0, 8, None, 2, 'PERCENT', None, None, None, ' dd %'],
#  ['science', False, 0, 8, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['3%', False, 0, 8, None, 2, 'PERCENT', None, None, None, ' d %'],
#  ['architecture', False, 0, 8, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['2015-2016', False, 0, 9, 0, 3, 'DATE', None, None, None, ' dddd - dddd'],
#  ['Notre Dame', False, 0, 9, 0, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ['ranked', False, 0, 9, 0, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['18th', False, 0, 9, 0, 1, 'ORDINAL', None, None, None, ' ddxx'],
#  ['overall', False, 0, 9, 0, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['national', False, 0, 9, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['universities', False, 0, 9, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['the United States',
#   False,
#   0,
#   9,
#   0,
#   3,
#   'GPE',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx'],
#  ["U.S. News & World Report's",
#   False,
#   0,
#   9,
#   0,
#   6,
#   'ORG',
#   None,
#   None,
#   None,
#   " X.X. Xxxx & Xxxxx Xxxxx 'x"],
#  ['Best', False, 0, 9, 0, 1, None, 'PROPN', 'NNP', 'compound', 'Xxxx'],
#  ['Colleges', False, 0, 9, 0, 1, None, 'PROPN', 'NNP', 'pobj', 'Xxxxx'],
#  ['2014', False, 0, 9, 1, 1, 'DATE', None, None, None, ' dddd'],
#  ['USA Today', True, 0, 9, 1, 2, 'ORG', None, None, None, ' XXX Xxxxx'],
#  ['ranked', False, 0, 9, 1, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['Notre Dame', False, 0, 9, 1, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ['10th', False, 0, 9, 1, 1, 'ORDINAL', None, None, None, ' ddxx'],
#  ['overall', False, 0, 9, 1, 1, None, 'NOUN', 'NN', 'advmod', 'xxxx'],
#  ['American', False, 0, 9, 1, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['universities', False, 0, 9, 1, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['based', False, 0, 9, 1, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['data', False, 0, 9, 1, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['College', False, 0, 9, 1, 1, None, 'PROPN', 'NNP', 'compound', 'Xxxxx'],
#  ['Factual', False, 0, 9, 1, 1, None, 'PROPN', 'NNP', 'pobj', 'Xxxxx'],
#  ['Forbes.com', False, 0, 9, 2, 1, 'ORG', None, None, None, ' Xxxxx.xxx'],
#  ['America', False, 0, 9, 2, 1, 'GPE', None, None, None, ' Xxxxx'],
#  ['Best', False, 0, 9, 2, 1, None, 'PROPN', 'NNP', 'compound', 'Xxxx'],
#  ['Colleges', False, 0, 9, 2, 1, None, 'PROPN', 'NNPS', 'nsubj', 'Xxxxx'],
#  ['ranks', False, 0, 9, 2, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['Notre Dame', False, 0, 9, 2, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ['colleges', False, 0, 9, 2, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['the United States',
#   False,
#   0,
#   9,
#   2,
#   3,
#   'GPE',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx'],
#  ['2015', False, 0, 9, 2, 1, 'DATE', None, None, None, ' dddd'],
#  ['Research Universities',
#   False,
#   0,
#   9,
#   2,
#   2,
#   'ORG',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['1st', False, 0, 9, 2, 1, 'ORDINAL', None, None, None, ' dxx'],
#  ['Midwest', False, 0, 9, 2, 1, 'LOC', None, None, None, ' Xxxxx'],
#  ['U.S. News & World Report',
#   False,
#   0,
#   9,
#   3,
#   5,
#   'ORG',
#   None,
#   None,
#   None,
#   ' X.X. Xxxx & Xxxxx Xxxxx'],
#  ['lists', False, 0, 9, 3, 1, None, 'VERB', 'VBZ', 'ROOT', 'xxxx'],
#  ['Notre Dame Law School',
#   False,
#   0,
#   9,
#   3,
#   4,
#   'ORG',
# ...
#  ['compare', False, 0, 11, 0, 1, None, 'VERB', 'VB', 'xcomp', 'xxxx'],
#  ['lift', False, 0, 11, 0, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['drag', False, 0, 11, 0, 1, None, 'VERB', 'VB', 'advcl', 'xxxx'],
#  ['aeronautical', False, 0, 11, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['models', False, 0, 11, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['Around 1899', True, 0, 11, 1, 2, 'DATE', None, None, None, ' Xxxxx dddd'],
#  ['Professor', False, 0, 11, 1, 1, None, 'PROPN', 'NNP', 'compound', 'Xxxxx'],
#  ['Jerome Green',
#   False,
#   0,
#   11,
#   1,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['first', False, 0, 11, 1, 1, 'ORDINAL', None, None, None, ' xxxx'],
#  ['American', False, 0, 11, 1, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['send', False, 0, 11, 1, 1, None, 'VERB', 'VB', 'xcomp', 'xxxx'],
#  ['wireless', False, 0, 11, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['message', False, 0, 11, 1, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['1931', False, 0, 11, 2, 1, 'DATE', None, None, None, ' dddd'],
#  ['Father', False, 0, 11, 2, 1, None, 'PROPN', 'NNP', 'compound', 'Xxxxx'],
#  ['Julius Nieuwland',
#   False,
#   0,
#   11,
#   2,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['performed', False, 0, 11, 2, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['early', False, 0, 11, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['work', False, 0, 11, 2, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['basic', False, 0, 11, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['reactions', False, 0, 11, 2, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['create', False, 0, 11, 2, 1, None, 'VERB', 'VB', 'xcomp', 'xxxx'],
#  ['neoprene', False, 0, 11, 2, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['Study', False, 0, 11, None, 1, None, 'NOUN', 'NN', 'nsubj', 'Xxxxx'],
#  ['nuclear', False, 0, 11, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['physics', False, 0, 11, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['university', False, 0, 11, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['began', False, 0, 11, None, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['building', False, 0, 11, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['nuclear', False, 0, 11, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['accelerator', False, 0, 11, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['1936', False, 0, 11, None, 1, 'DATE', None, None, None, ' dddd'],
#  ['continues', False, 0, 11, None, 1, None, 'VERB', 'VBZ', 'conj', 'xxxx'],
#  ['partly', False, 0, 11, None, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['partnership', False, 0, 11, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['the Joint Institute for Nuclear Astrophysics',
#   False,
#   0,
#   11,
#   None,
#   6,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx xxx Xxxxx Xxxxx'],
#  ['The Lobund Institute',
#   True,
#   0,
#   12,
#   0,
#   3,
#   'ORG',
#   None,
#   None,
#   None,
#   ' Xxx Xxxxx Xxxxx'],
#  ['grew', False, 0, 12, 0, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['pioneering', False, 0, 12, 0, 1, None, 'VERB', 'VBG', 'amod', 'xxxx'],
#  ['research', False, 0, 12, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['germ', False, 0, 12, 0, 1, None, 'NOUN', 'NN', 'npadvmod', 'xxxx'],
#  ['free', False, 0, 12, 0, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['life', False, 0, 12, 0, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['began', False, 0, 12, 0, 1, None, 'VERB', 'VBD', 'relcl', 'xxxx'],
#  ['1928', True, 0, 12, 0, 1, 'DATE', None, None, None, ' dddd'],
#  ['area', False, 0, 12, 1, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['research', False, 0, 12, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['originated', False, 0, 12, 1, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['question', False, 0, 12, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['posed', False, 0, 12, 1, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['Pasteur', False, 0, 12, 1, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['animal', False, 0, 12, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['life', False, 0, 12, 1, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['possible', False, 0, 12, 1, 1, None, 'ADJ', 'JJ', 'acomp', 'xxxx'],
#  ['bacteria', False, 0, 12, 1, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['taken', False, 0, 12, 2, 1, None, 'VERB', 'VBN', 'advcl', 'xxxx'],
#  ['idea', False, 0, 12, 2, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['research', False, 0, 12, 2, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['short', False, 0, 12, 2, 1, None, 'ADJ', 'JJ', 'advmod', 'xxxx'],
#  ['lived', False, 0, 12, 2, 1, None, 'VERB', 'VBN', 'acomp', 'xxxx'],
#  ['inconclusive', False, 0, 12, 2, 1, None, 'ADJ', 'JJ', 'conj', 'xxxx'],
#  ['Lobund', False, 0, 12, 3, 1, 'GPE', None, None, None, ' Xxxxx'],
#  ['first', False, 0, 12, 3, 1, 'ORDINAL', None, None, None, ' xxxx'],
#  ['research', False, 0, 12, 3, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['organization', False, 0, 12, 3, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['answer', False, 0, 12, 3, 1, None, 'VERB', 'VB', 'relcl', 'xxxx'],
#  ['definitively', False, 0, 12, 3, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['life', False, 0, 12, 3, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['possible', False, 0, 12, 3, 1, None, 'ADJ', 'JJ', 'acomp', 'xxxx'],
#  ['prolonged', False, 0, 12, 3, 1, None, 'VERB', 'VBN', 'conj', 'xxxx'],
#  ['generations', False, 0, 12, 3, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['objective', False, 0, 12, 4, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['merely', False, 0, 12, 4, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['answer', False, 0, 12, 4, 1, None, 'VERB', 'VB', 'xcomp', 'xxxx'],
#  ['Pasteur', False, 0, 12, 4, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['question', False, 0, 12, 4, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['produce', False, 0, 12, 4, 1, None, 'VERB', 'VB', 'conj', 'xxxx'],
#  ['germ', False, 0, 12, 4, 1, None, 'NOUN', 'NN', 'nmod', 'xxxx'],
#  ['free', False, 0, 12, 4, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['animal', False, 0, 12, 4, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['new', False, 0, 12, 4, 1, None, 'ADJ', 'JJ', 'amod', 'xxx'],
#  ['tool', False, 0, 12, 4, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['biological', False, 0, 12, 4, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['medical', False, 0, 12, 4, 1, None, 'ADJ', 'JJ', 'conj', 'xxxx'],
#  ['research', False, 0, 12, 4, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['objective', False, 0, 12, 5, 1, None, 'NOUN', 'NN', 'nsubjpass', 'xxxx'],
#  ['reached', False, 0, 12, 5, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['years', False, 0, 12, 5, 1, 'DATE', None, None, None, ' xxxx'],
#  ['Lobund', False, 0, 12, 5, 1, None, 'PROPN', 'NNP', 'nsubj', 'Xxxxx'],
#  ['unique', False, 0, 12, 5, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['center', False, 0, 12, 5, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['study', False, 0, 12, 5, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['production', False, 0, 12, 5, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['germ', False, 0, 12, 5, 1, None, 'NOUN', 'NN', 'nmod', 'xxxx'],
#  ['free', False, 0, 12, 5, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['animals', False, 0, 12, 5, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['use', False, 0, 12, 5, 1, None, 'NOUN', 'NN', 'pobj', 'xxx'],
#  ['biological', False, 0, 12, 5, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['medical', False, 0, 12, 5, 1, None, 'ADJ', 'JJ', 'conj', 'xxxx'],
#  ['investigations', False, 0, 12, 5, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['Today', False, 0, 12, 6, 1, 'DATE', None, None, None, ' Xxxxx'],
#  ['work', False, 0, 12, 6, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['spread', False, 0, 12, 6, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['universities', False, 0, 12, 6, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['beginning', False, 0, 12, 7, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['the Department of Biology',
#   False,
#   0,
#   12,
#   7,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxxx'],
#  ['program', False, 0, 12, 7, 1, None, 'NOUN', 'NN', 'conj', 'xxxx'],
#  ['leading', False, 0, 12, 7, 1, None, 'VERB', 'VBG', 'acl', 'xxxx'],
#  ['master', False, 0, 12, 7, 1, None, 'NOUN', 'NN', 'poss', 'xxxx'],
#  ['degree', False, 0, 12, 7, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['accompanied', False, 0, 12, 7, 1, None, 'VERB', 'VBD', 'conj', 'xxxx'],
#  ['research', False, 0, 12, 7, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['program', False, 0, 12, 7, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['the 1940s', True, 0, 12, 8, 2, 'DATE', None, None, None, ' xxx ddddx'],
#  ['Lobund', False, 0, 12, 8, 1, 'GPE', None, None, None, ' Xxxxx'],
#  ['achieved', False, 0, 12, 8, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['independent', False, 0, 12, 8, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['status', False, 0, 12, 8, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['purely', False, 0, 12, 8, 1, None, 'ADV', 'RB', 'amod', 'xxxx'],
#  ['research', False, 0, 12, 8, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['organization', False, 0, 12, 8, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['1950', True, 0, 12, 8, 1, 'DATE', None, None, None, ' dddd'],
#  ['raised', False, 0, 12, 8, 1, None, 'VERB', 'VBN', 'conj', 'xxxx'],
#  ['status', False, 0, 12, 8, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['Institute', False, 0, 12, 8, 1, None, 'PROPN', 'NNP', 'pobj', 'Xxxxx'],
#  ['1958', False, 0, 12, None, 1, 'DATE', None, None, None, ' dddd'],
#  ['brought', False, 0, 12, None, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['the Department of Biology',
#   False,
#   0,
#   12,
#   None,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx xx Xxxxx'],
#  ['integral', False, 0, 12, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['department', False, 0, 12, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['program', False, 0, 12, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['leading', False, 0, 12, None, 1, None, 'VERB', 'VBG', 'acl', 'xxxx'],
#  ['degree', False, 0, 12, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['PhD', False, 0, 12, None, 1, 'WORK_OF_ART', None, None, None, ' XxX'],
#  ['Gnotobiotics', False, 0, 12, None, 1, 'GPE', None, None, None, ' Xxxxx'],
#  ['The Review of Politics',
#   True,
#   0,
#   13,
#   0,
#   4,
#   'ORG',
#   None,
#   None,
#   None,
#   ' Xxx Xxxxx xx Xxxxx'],
#  ['founded', False, 0, 13, 0, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['1939', False, 0, 13, 0, 1, 'DATE', None, None, None, ' dddd'],
#  ['Gurian', False, 0, 13, 0, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['modeled', False, 0, 13, 0, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['German Catholic',
#   False,
#   0,
#   13,
#   0,
#   2,
#   'NORP',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['journals', False, 0, 13, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['quickly', False, 0, 13, 1, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['emerged', False, 0, 13, 1, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['international', False, 0, 13, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['Catholic', False, 0, 13, 1, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['intellectual', False, 0, 13, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['revival', False, 0, 13, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['offering', False, 0, 13, 1, 1, None, 'VERB', 'VBG', 'advcl', 'xxxx'],
#  ['alternative', False, 0, 13, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['vision', False, 0, 13, 1, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['positivist', False, 0, 13, 1, 1, None, 'VERB', 'VB', 'advcl', 'xxxx'],
#  ['philosophy', False, 0, 13, 1, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['44 years', False, 0, 13, 2, 2, 'DATE', None, None, None, ' dd xxxx'],
#  ['Review', False, 0, 13, 2, 1, 'ORG', None, None, None, ' Xxxxx'],
#  ['edited', False, 0, 13, 2, 1, None, 'VERB', 'VBN', 'ROOT', 'xxxx'],
#  ['Gurian', False, 0, 13, 2, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['Matthew Fitzsimons',
#   False,
#   0,
#   13,
#   2,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['Frederick Crosson',
#   False,
#   0,
#   13,
#   2,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['Thomas Stritch',
#   False,
#   0,
#   13,
#   2,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ['Intellectual', False, 0, 13, 3, 1, None, 'ADJ', 'JJ', 'amod', 'Xxxxx'],
#  ['leaders', False, 0, 13, 3, 1, None, 'NOUN', 'NNS', 'nsubj', 'xxxx'],
#  ['included', False, 0, 13, 3, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['Gurian', False, 0, 13, 3, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['Jacques Maritain',
#   False,
#   0,
#   13,
#   3,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxxx Xxxxx'],
#  ["Frank O'Malley",
#   False,
#   0,
#   13,
#   3,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   " Xxxxx X'Xxxxx"],
#  ['Leo Richard Ward',
#   False,
#   0,
#   13,
#   3,
#   3,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxx Xxxxx Xxxx'],
#  ['F. A. Hermens',
#   False,
#   0,
#   13,
#   3,
#   3,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' X. X. Xxxxx'],
#  ['John U. Nef',
#   False,
#   0,
#   13,
#   3,
#   3,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxx X. Xxx'],
#  ['major', False, 0, 13, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['forum', False, 0, 13, None, 1, None, 'NOUN', 'NN', 'attr', 'xxxx'],
#  ['political', False, 0, 13, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['ideas', False, 0, 13, None, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['modern', False, 0, 13, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['political', False, 0, 13, None, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['concerns', False, 0, 13, None, 1, None, 'NOUN', 'NNS', 'conj', 'xxxx'],
#  ['especially', False, 0, 13, None, 1, None, 'ADV', 'RB', 'advmod', 'xxxx'],
#  ['Catholic', False, 0, 13, None, 1, 'NORP', None, None, None, ' Xxxxx'],
#  ['scholastic', False, 0, 13, None, 1, None, 'ADJ', 'JJ', 'conj', 'xxxx'],
#  ['tradition', False, 0, 13, None, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['2012[update',
#   False,
#   0,
#   14,
#   0,
#   1,
#   'CARDINAL',
#   None,
#   None,
#   None,
#   ' dddd[xxxx'],
#  ['research', False, 0, 14, 0, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['continued', False, 0, 14, 0, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['fields', False, 0, 14, 0, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['university', False, 0, 14, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['president', False, 0, 14, 1, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['John Jenkins',
#   True,
#   0,
#   14,
#   1,
#   2,
#   'PERSON',
#   None,
#   None,
#   None,
#   ' Xxxx Xxxxx'],
#  ['described', False, 0, 14, 1, 1, None, 'VERB', 'VBD', 'ROOT', 'xxxx'],
#  ['hope', False, 0, 14, 1, 1, None, 'NOUN', 'NN', 'dobj', 'xxxx'],
#  ['Notre Dame', True, 0, 14, 1, 2, 'FAC', None, None, None, ' Xxxxx Xxxx'],
#  ['one', False, 0, 14, 1, 1, 'CARDINAL', None, None, None, ' xxx'],
#  ['pre', False, 0, 14, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxx'],
#  ['eminent', False, 0, 14, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['research', False, 0, 14, 1, 1, None, 'NOUN', 'NN', 'compound', 'xxxx'],
#  ['institutions', False, 0, 14, 1, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['world', False, 0, 14, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['inaugural', False, 0, 14, 1, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['address', False, 0, 14, 1, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['university', False, 0, 14, 2, 1, None, 'NOUN', 'NN', 'nsubj', 'xxxx'],
#  ['multi', False, 0, 14, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['disciplinary', False, 0, 14, 2, 1, None, 'ADJ', 'JJ', 'amod', 'xxxx'],
#  ['institutes', False, 0, 14, 2, 1, None, 'NOUN', 'NNS', 'dobj', 'xxxx'],
#  ['devoted', False, 0, 14, 2, 1, None, 'VERB', 'VBN', 'acl', 'xxxx'],
#  ['research', False, 0, 14, 2, 1, None, 'NOUN', 'NN', 'pobj', 'xxxx'],
#  ['varying', False, 0, 14, 2, 1, None, 'VERB', 'VBG', 'amod', 'xxxx'],
#  ['fields', False, 0, 14, 2, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ['including', False, 0, 14, 2, 1, None, 'VERB', 'VBG', 'prep', 'xxxx'],
#  ['the Medieval Institute',
#   False,
#   0,
#   14,
#   2,
#   3,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx'],
#  ['the Kellogg Institute for International Studies',
#   False,
#   0,
#   14,
#   2,
#   6,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxxx Xxxxx xxx Xxxxx Xxxxx'],
#  ['the Kroc Institute for International Peace',
#   False,
#   0,
#   14,
#   2,
#   6,
#   'ORG',
#   None,
#   None,
#   None,
#   ' xxx Xxxx Xxxxx xxx Xxxxx Xxxxx'],
#  ['studies', False, 0, 14, 2, 1, None, 'NOUN', 'NNS', 'pobj', 'xxxx'],
#  ...]

# %%
wordsDf = pd.DataFrame(words, columns=wordColums)
wordsDf.head()
# Out:
#               text  isAnswer  titleId  paragrapghId  sentenceId  wordCount  \
# 0  Architecturally     False        0             0         0.0          1
# 1           school     False        0             0         0.0          1
# 2         Catholic     False        0             0         0.0          1
# 3        character     False        0             0         0.0          1
# 4             Atop     False        0             0         1.0          1
#
#     NER   POS   TAG     DEP   shape
# 0  None   ADV    RB  advmod   Xxxxx
# 1  None  NOUN    NN   nsubj    xxxx
# 2  NORP  None  None    None   Xxxxx
# 3  None  NOUN    NN    dobj    xxxx
# 4  None   ADP    IN    prep    Xxxx

# %%
print("Total words for 2 articles:", len(wordsDf))
# Out:
# Total words for 2 articles: 8596

# %% [markdown]
# ## Generating the entire word dataset

# %%
wordPickleName = '../data/pickles/wordsDf.pkl'

#If the dataframe is already generated, load it.
if (pickleExists(wordPickleName)):
    print("Pickle found. Saved some time.")
    wordsDf = loadPickle(wordPickleName)
else:
    #Extracting words
    words = []

#     titlesCount = len(df['data'])   
    titlesCount = 2   

    for titleId in tqdm(range(titlesCount)):
        paragraphsCount = len(df['data'][titleId]['paragraphs'])

#         printProgress(titleId, titlesCount - 1)

        for paragraphId in range(paragraphsCount):
            addWordsForParagrapgh(words, titleId, paragraphId)
    
    #Create the dataframe
    wordColums = ['text', 'isAnswer', 'titleId', 'paragrapghId', 'sentenceId','wordCount', 'NER', 'POS', 'TAG', 'DEP','shape']
    wordsDf = pd.DataFrame(words, columns=wordColums)
    
    #Pickle the result
    dumpPickle(wordPickleName, wordsDf)
    print("Result was not pickled. You had to wait.")
# Out:
# Pickle found. Saved some time.

# %% [markdown]
# Total extracted words:

# %%
print("Total words for all articles:", len(wordsDf))
# Out:
# Total words for all articles: 8678

# %% [markdown]
# Check what percentage of the extracted words are answers in the dataframe. They should be pretty low

# %%
totalAnswers = len(wordsDf[wordsDf['isAnswer'] == True])
print(totalAnswers, 'total answers', '{:.2f}%'.format((totalAnswers / len(wordsDf)) * 100), 'of all words are answers.')
# Out:
# 383 total answers 4.41% of all words are answers.
